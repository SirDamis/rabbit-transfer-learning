# %%
# !nvidia-smi
# Out:
# Mon Feb 13 04:37:00 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P8    10W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/RabbitDetect-1

# %%
# !pip install ultralytics
from IPython import display

display.clear_output()
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.35 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.4/78.2 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YOUR-API-KEY")
project = rf.workspace("adedeji-oluwadamisola").project("rabbitdetect")
dataset = project.version(1).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.35, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to RabbitDetect-1 in yolov8:: 100%|██████████| 724/724 [00:00<00:00, 2001.24it/s]

# %%
# %cd /content/RabbitDetect-1
# !pwd
# Out:
# /content/RabbitDetect-1
# /content/RabbitDetect-1

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Train the model
model.train(data="/content/RabbitDetect-1/data.yaml", epochs=100, imgsz=640, plots=True)
# Out:
# Ultralytics YOLOv8.0.35 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %%
# !yolo detect predict model=path/to/best.pt source="https://ultralytics.com/images/bus.jpg
model = YOLO("/content/RabbitDetect-1/runs/detect/train2/weights/best.pt")  # load a custom model

# Predict with the model
results = model("https://c8.alamy.com/comp/W7XDFE/feral-domestic-rabbit-oryctolagus-cuniculus-lying-on-its-side-whilst-sleeping-okunojima-island-also-known-as-rabbit-island-hiroshima-japan-W7XDFE.jpg")  # p
# Out:
# Ultralytics YOLOv8.0.35 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# ...
# 0.00B [00:00, ?B/s]
# image 1/1 /content/RabbitDetect-1/feral-domestic-rabbit-oryctolagus-cuniculus-lying-on-its-side-whilst-sleeping-okunojima-island-also-known-as-rabbit-island-hiroshima-japan-W7XDFE.jpg: 480x640 2 rabbits, 19.6ms
# Speed: 0.5ms pre-process, 19.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
# !cp /content/RabbitDetect-1/runs/detect/train2/weights/best.pt /content/drive/MyDrive/rabbit-feature-extractor
